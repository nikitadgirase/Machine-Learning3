# %%
import numpy as np
import matplotlib.pyplot as plt
from tqdm import tqdm

# %%
k=10
num_problems=2000

q_star=np.random.normal(0,1,(num_problems,k))
arms=[0]*k

# %%
for i in range(10):
    arms[i]=np.random.normal(q_star[0,i],1,2000)

# %%
plt.figure(figsize=(12,8))
plt.ylabel('Rewards Distrubution')
plt.xlabel('Actions')
plt.xticks(range(1,11))
plt.yticks(np.arange(-5,5,0.5))
# Out:
# ([<matplotlib.axis.YTick at 0x1bd3cbaee90>,
#   <matplotlib.axis.YTick at 0x1bd3cbacf50>,
#   <matplotlib.axis.YTick at 0x1bd3cb97a90>,
#   <matplotlib.axis.YTick at 0x1bd3cc0fd10>,
#   <matplotlib.axis.YTick at 0x1bd3cc16110>,
#   <matplotlib.axis.YTick at 0x1bd3cc1c5d0>,
#   <matplotlib.axis.YTick at 0x1bd3cc1e850>,
#   <matplotlib.axis.YTick at 0x1bd3cc14d10>,
#   <matplotlib.axis.YTick at 0x1bd3cc25050>,
#   <matplotlib.axis.YTick at 0x1bd3cc27390>,
#   <matplotlib.axis.YTick at 0x1bd3cc29990>,
#   <matplotlib.axis.YTick at 0x1bd3cc2bd90>,
#   <matplotlib.axis.YTick at 0x1bd3cc25810>,
#   <matplotlib.axis.YTick at 0x1bd3cc32910>,
#   <matplotlib.axis.YTick at 0x1bd3cc34c10>,
#   <matplotlib.axis.YTick at 0x1bd3cc36f90>,
#   <matplotlib.axis.YTick at 0x1bd3cc393d0>,
#   <matplotlib.axis.YTick at 0x1bd3cc353d0>,
#   <matplotlib.axis.YTick at 0x1bd3cc44350>,
#   <matplotlib.axis.YTick at 0x1bd3cc46610>],
#  [Text(0, -5.0, '−5.0'),
#   Text(0, -4.5, '−4.5'),
#   Text(0, -4.0, '−4.0'),
#   Text(0, -3.5, '−3.5'),
#   Text(0, -3.0, '−3.0'),
#   Text(0, -2.5, '−2.5'),
#   Text(0, -2.0, '−2.0'),
#   Text(0, -1.5, '−1.5'),
#   Text(0, -1.0, '−1.0'),
#   Text(0, -0.5, '−0.5'),
#   Text(0, 0.0, '0.0'),
#   Text(0, 0.5, '0.5'),
#   Text(0, 1.0, '1.0'),
#   Text(0, 1.5, '1.5'),
#   Text(0, 2.0, '2.0'),
#   Text(0, 2.5, '2.5'),
#   Text(0, 3.0, '3.0'),
#   Text(0, 3.5, '3.5'),
#   Text(0, 4.0, '4.0'),
#   Text(0, 4.5, '4.5')])

# %%
plt.violinplot(arms,positions=range(1,11),showmedians=True)
plt.show()
